# %%
from agents.connection_finder import ConnectionFinder
from agents.explanation_builder import ExplanationBuilder

from IPython.display import display, HTML
import asyncio

# %%
connection_finder = ConnectionFinder()
explainer = ExplanationBuilder()

# %%
level = "beginner"
concept_a = "Quantum Entanglement"
concept_b = "Blockchain"
concept_a_knowledge = 0
concept_b_knowledge = 0
education_system = "french"
education_level = "high school"

profile = {
    "knowledge_level": level,
    "education_level": education_level,
    "education_system": education_system,
    "concept_a_knowledge": concept_a_knowledge,
    "concept_b_knowledge": concept_b_knowledge,
}

ctx = {
    "history": None,
    "level": level,
    "session_id": None,
    "concept_a": concept_a,
    "concept_b": concept_b,
    "profile": profile,
    "feedback_guidance": None
}

# %%
connections = await connection_finder.find(concept_a, concept_b, level, ctx)

# %%
path = connections["path"]

html = f"""
<style>
.path {{
    font-family: system-ui, -apple-system, BlinkMacSystemFont;
    font-size: 16px;
    padding: 8px 12px;
    background: #f8f9fa;
    border-radius: 8px;
    display: inline-block;
}}
.arrow {{
    color: #888;
    margin: 0 6px;
}}
.node {{
    font-weight: 600;
    color: #222;
}}
</style>

<div class="path">
    {"".join(
        f'<span class="node">{p}</span>' if i == len(path)-1
        else f'<span class="node">{p}</span><span class="arrow">→</span>'
        for i, p in enumerate(path)
    )}
</div>
"""

display(HTML(html))
# Out:
# <style>
# .path {
#     font-family: system-ui, -apple-system, BlinkMacSystemFont;
#     font-size: 16px;
#     padding: 8px 12px;
#     background: #f8f9fa;
#     border-radius: 8px;
#     display: inline-block;
# }
# .arrow {
#     color: #888;
#     margin: 0 6px;
# }
# .node {
#     font-weight: 600;
#     color: #222;
# }
# </style>
#
# <div class="path">
#     <span class="node">Quantum Entanglement</span><span class="arrow">→</span><span class="node">Information Theory</span><span class="arrow">→</span><span class="node">Cryptography</span><span class="arrow">→</span><span class="node">Distributed Systems</span><span class="arrow">→</span><span class="node">Blockchain</span><span class="arrow">→</span><span class="node">Data Integrity</span>
# </div>

# %% [markdown]
# #### **Note**: Sometimes, the json parsing can fail even though i've added a json extraction function. In case you get an error, or the cell outputs the results of the LLM as a json text instead of a json object, ``rerun the cell``, it should work

# %%
narrative = await explainer.build(
    connections,
    level,
    profile=profile,
    guidance=None,
    concept_a=concept_a,
    concept_b=concept_b,
)
            
narrative = narrative or {}
explanations = narrative.get("explanation")
analogies = narrative.get("analogies", [])

# %%
display(HTML(explanations))
# Out:
# <h2>Connecting Quantum Entanglement to the World of Data</h2>
# <p>Let's explore how seemingly strange ideas like <strong>quantum entanglement</strong> can be connected to things you learn about in computer science and how they relate to keeping information safe and reliable. It might seem confusing at first, but we'll break it down step-by-step.</p>
# <h3>Overview</h3>
# <p>Essentially, quantum entanglement is a weird effect in physics where two tiny particles become linked together in a special way. When you measure something about one particle, you instantly know something about the other, no matter how far apart they are! This concept can be used as a building block for understanding how complex systems like <strong>distributed systems</strong> and <strong>blockchain</strong> can work, especially when ensuring <strong>data integrity</strong>.</p>
# <h3>The Connection – Step-by-Step</h3>
# <ol>
# <li>
# <p><strong>Linked Information</strong>: Imagine two coins flipped at the same time. In quantum entanglement, it's like those coins are linked – if one always lands on heads, you instantly know the other landed on tails, even if they're miles apart. This linked information is key. </p>
# </li>
# <li>
# <p><strong>Distributed Agreement</strong>: In <strong>distributed systems</strong> (like many apps you use), different computers work together to complete a task. Quantum entanglement could inspire new ways to ensure these computers <em>always</em> agree on the same information. Think of it like needing a very precise, instant way to synchronize data across multiple locations.</p>
# </li>
# <li>
# <p><strong>Cryptography &amp; Data Integrity</strong>:  <strong>Cryptography</strong> (the science of secret codes) uses the principle of linked information to secure data. <strong>Blockchain</strong> leverages this idea too. Each block in the chain is linked to the previous one, forming an unbroken record. If someone tries to change one block, the change instantly affects all subsequent blocks – like knowing the linked coins were altered, because the connection is broken.</p>
# </li>
# </ol>
# <p><strong>Concrete Example</strong>: Imagine a group of friends sending messages.  They all have a secret code that depends on a specific event (like a flipped coin). If one person changes their message, everyone else automatically adjusts their messages accordingly, because they’re linked together.</p>
# <h3>Analogies</h3>
# <ul>
# <li>"Think of entangled particles like a pair of magic gloves – if you change the color of one glove, the other one instantly changes color too, no matter how far apart they are."</li>
# <li>"It's like a secret handshake – if one person performs the handshake correctly, everyone else in the group knows they're part of the group."</li>
# <li>"Quantum entanglement is a way of instantly sharing information, like sending a secret signal without using a wire."</li>
# </ul>

# %%
for analogy in analogies:
    display(HTML(analogy))
# Out:
# Think of entangled particles like a pair of magic gloves – if you change the color of one glove, the other one instantly changes color too, no matter how far apart they are.
# It's like a secret handshake – if one person performs the handshake correctly, everyone else in the group knows they're part of the group.
# Quantum entanglement is a way of instantly sharing information, like sending a secret signal without using a wire.

# %% [markdown]
# # First Mitigation bias strategy: two new agents !!

# %%
from agents.bias_monitor import BiasMonitor
from agents.content_reviewer import ContentReviewer

bias = BiasMonitor()
reviewer = ContentReviewer()

# %%
bundle = {
    'connections': connections,
    'explanations': explanations,
    'analogies': analogies
}

# %%
bias_review_task = bias.review(bundle)
content_review_task = reviewer.evaluate(
    bundle,
    level=level,
    profile=profile,
    concept_a=concept_a,
    concept_b=concept_b,
)

bias_review, content_review = await asyncio.gather(bias_review_task, content_review_task)

# %%
biases = bias_review["raw"]
for bias_element in biases:
    display(HTML(bias_element))
# Out:
# Cultural bias: The 'magic gloves' analogy is heavily reliant on a Western, magical-thinking understanding of the world. Suggest: Use a more universally relatable analogy, such as a synchronized dance or a carefully orchestrated event, to explain the instantaneous correlation.
# Language accessibility: The explanation uses dense terminology ('quantum entanglement,' 'distributed systems,' 'data integrity') without sufficient context or simplification. Suggest: Begin with a more accessible definition of quantum entanglement before introducing complex concepts, and provide simpler explanations for technical terms.
# Limited analogies: The analogies provided are somewhat simplistic and may not fully convey the depth of the concept. Suggest: Include a broader range of analogies, potentially drawing from fields like biology (e.g., a synchronized flock of birds) or even everyday social interactions (e.g., coordinated team effort) to aid understanding.
# Demographic bias: The 'group of friends sending messages' example leans towards a specific social dynamic (a group of friends) that might not resonate with all learners. Suggest: Reframe the example with more diverse scenarios, perhaps involving a group of robots performing a synchronized task or a team of researchers collaborating on a project.

# %%
content_review
# Out:
# {'level_alignment': True,
#  'reading_level': 'High school / B1-B2 CEFR',
#  'issues': [],
#  'suggested_actions': [],
#  'bias_risk': 'low'}

# %%
bias_review
# Out:
# {'has_bias': True,
#  'raw': ["Cultural bias: The 'magic gloves' analogy is heavily reliant on a Western, magical-thinking understanding of the world. Suggest: Use a more universally relatable analogy, such as a synchronized dance or a carefully orchestrated event, to explain the instantaneous correlation.",
#   "Language accessibility: The explanation uses dense terminology ('quantum entanglement,' 'distributed systems,' 'data integrity') without sufficient context or simplification. Suggest: Begin with a more accessible definition of quantum entanglement before introducing complex concepts, and provide simpler explanations for technical terms.",
#   'Limited analogies: The analogies provided are somewhat simplistic and may not fully convey the depth of the concept. Suggest: Include a broader range of analogies, potentially drawing from fields like biology (e.g., a synchronized flock of birds) or even everyday social interactions (e.g., coordinated team effort) to aid understanding.',
#   "Demographic bias: The 'group of friends sending messages' example leans towards a specific social dynamic (a group of friends) that might not resonate with all learners. Suggest: Reframe the example with more diverse scenarios, perhaps involving a group of robots performing a synchronized task or a team of researchers collaborating on a project."]}

# %%
mitigation_triggered = bias_review.get("has_bias") or not content_review.get("level_alignment", True)
mitigation_triggered
# Out:
# True

# %%
mitigation_triggered = bias_review.get("has_bias") or not content_review.get("level_alignment", True)

retry_strategies = [ 
    "CRITICAL: Address the following issues with high priority. ",
        "SIMPLIFY: Use simpler language and clearer structure. ",
            "RESTRUCTURE: Completely reorganize the explanation with a fresh approach. "
]

retry_count = 0
MAX_RETRIES = 2

new_narrative = narrative
new_explanations = explanations
new_analogies = analogies

while mitigation_triggered:
    if retry_count >= MAX_RETRIES:
        print("Max retries exceeded, no more bias mitigations attempts")
        break
    
    strategy = retry_strategies[retry_count]
    retry_count+=1
    suggestions = [strategy]

    if content_review and content_review.get("suggested_actions"):
        suggestions.append("Reviewer actions: " + ", ".join(content_review["suggested_actions"]))
    if bias_review and bias_review.get("raw"):
        suggestions.append("Bias adjustments: " + " | ".join(bias_review["raw"]))

    mitigation_guidance = " ".join(suggestions) if len(suggestions) !=0 else "Rewrite for clarity and inclusivity."
    new_narrative = await explainer.build(
        connections,
        level,
        profile=profile,
        guidance=mitigation_guidance,
        concept_a=concept_a,
        concept_b=concept_b,
    )
            
    new_narrative = new_narrative or {}
    new_explanations = new_narrative.get("explanation")
    new_analogies = new_narrative.get("analogies", [])

    new_bundle = {
        'connections': connections,
        'explanations': new_explanations,
        'analogies': new_analogies
    }

    # Re-review for bias and alignment
    new_bias_review_task = bias.review(new_bundle)
    new_content_review_task = reviewer.evaluate(
        new_bundle,
        level=level,
        profile=profile,
        concept_a=concept_a,
        concept_b=concept_b,
    )

    bias_review, content_review = await asyncio.gather(new_bias_review_task, new_content_review_task)
    mitigation_triggered = bias_review.get("has_bias") or not content_review.get("level_alignment", True)
    
    if not mitigation_triggered:
        break
# Out:
# Max retries exceeded, no more bias mitigations attempts

# %%
display(HTML(new_explanations))
# Out:
# <h2>Connecting Quantum Entanglement to Data Integrity</h2>
# <p>This explanation will explore how the seemingly distant concepts of <strong>quantum entanglement</strong> and <strong>data integrity</strong> are actually linked, particularly through the lens of modern technology like <strong>distributed systems</strong> and <strong>blockchain</strong>. Let’s break it down step-by-step.</p>
# <p><strong>1. Understanding the Basics:</strong><br />
# *   <strong>Quantum Entanglement:</strong> Imagine two tiny particles linked together in a strange way. When you measure something about one particle, you instantly know something about the other, no matter how far apart they are. It’s like a secret connection.<br />
# *   <strong>Data Integrity:</strong> This means ensuring that information hasn't been changed or damaged. Think of a file you download – you want to be sure it's exactly what the creator intended.</p>
# <p><strong>2. The Connection: Correlated States</strong><br />
# *   Both entanglement and data integrity rely on the idea of <strong>correlated states</strong>. In entanglement, the particles' states are linked. In data integrity, the data's state (its values) is linked to a reliable source. If the source is compromised, the data’s integrity is lost.</p>
# <p><strong>3. Distributed Systems &amp; Blockchain as a Bridge:</strong><br />
# *   <strong>Distributed Systems</strong> (like cloud computing) involve multiple computers working together. They need to ensure that everyone has the same information – this is related to data integrity.<br />
# *   <strong>Blockchain</strong> is a special type of distributed system that uses ‘blocks’ of information linked together. Each block contains a ‘hash’ – a unique fingerprint – of the previous block. This creates a chain that's incredibly difficult to tamper with. This chain is similar to maintaining the entanglement of quantum states—any change to one block instantly affects the whole chain. </p>
# <p><strong>Example:</strong> Imagine a group of friends sending each other secret messages.  Each person has a special key (like the hash in blockchain). If someone tries to change a message in one person’s copy, the key will be wrong, and everyone else will know something is wrong. This mirrors how blockchain protects data integrity through a linked chain of verified information.</p>

# %%
for analogy in new_analogies:
    display(HTML(analogy))
# Out:
# Think of entangled particles like two identical twins – if you change something about one, you instantly know the change about the other, no matter where they are.
# A blockchain is like a very long, secure chain of Lego bricks, where each brick is connected to the one before it. If you try to pull one brick out, the whole chain falls apart.
# Data integrity is like a really complicated recipe, and blockchain is like having lots of chefs all independently checking the recipe to make sure it hasn't been messed with.

# %% [markdown]
# # Second bias mitigation strategy: Adding user feedback after answer for better prompting

# %%
from agents.feedback_adapter import FeedbackAdapter

feedback = FeedbackAdapter()

feedback_rows = [
    {
        "comments": "use a more simple language, i don't understand the complex terms",
        "rating":1
    }
]

guidance = feedback.summarise(feedback_rows,level)

# We set the feedback guidance to None before, this will set it to our new guidance for the model
if ctx["feedback_guidance"] is None:
    ctx["feedback_guidance"] = guidance

# %% [markdown]
# This guidance text will serve as a base guidance for the model. If after that we need to mitigate the bias, it will be added to the mitigation bias strategy (cf *`_compose_guidance_with_strategy`* in **Orchestrator**)

# %%
narrative = await explainer.build(
    connections,
    level,
    profile=profile,
    guidance=guidance, # here we add the feedback guidance
    concept_a=concept_a,
    concept_b=concept_b,
)
            
narrative = narrative or {}
explanations = narrative.get("explanation")
analogies = narrative.get("analogies", [])

# %%
display(HTML(explanations))
# Out:
# <h2>Connecting Quantum Entanglement to Blockchain: A Step-by-Step Guide</h2>
# <p>Let’s explore how seemingly different things like <strong>Quantum Entanglement</strong> and <strong>Blockchain</strong> are actually linked. Don’t worry about the complicated physics of entanglement right now – we'll focus on the core ideas.</p>
# <h3>Overview</h3>
# <p>Both entanglement and blockchain deal with making sure things are <strong>reliable</strong> and <strong>secure</strong>, even when they’re separate. Think about it like this: they both create trust in a system.</p>
# <h3>Step-by-Step Connection</h3>
# <ol>
# <li>
# <p><strong>Linked Information:</strong> Imagine two coins, one in Paris and one in New York. If they are linked, knowing the result of one instantly tells you the result of the other. Similarly, entanglement means two particles are linked, and measuring one instantly tells you about the other.</p>
# </li>
# <li>
# <p><strong>Trust Without Control:</strong> Blockchain is like a shared record book where every change is visible to everyone. No single person controls it, but it's very reliable because everyone agrees on the rules. Entanglement also works without a central controller; the connection is built-in.</p>
# </li>
# <li>
# <p><strong>Data Integrity:</strong> Blockchain ensures that information hasn't been tampered with because every block of data is linked to the previous one. Entanglement ensures that any change to one entangled particle instantly affects the other, acting as a built-in check for integrity.</p>
# </li>
# </ol>
# <p><strong>Concrete Example:</strong> Think of a group of friends who want to keep a secret. Every time someone adds to the secret, everyone else gets a copy. This makes it very hard for someone to sneakily change the secret without others noticing. Blockchain and entanglement both provide this ‘copy-and-verify’ mechanism, building trust in a distributed system.</p>
# <h3>Key Differences</h3>
# <p>Blockchain is based on computers and math, while entanglement is based on the strange behavior of tiny particles. However, both are about building reliable systems where trust is built-in, not based on a single person or organization.</p>
